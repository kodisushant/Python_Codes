# %%
import io
with open("domo.docx","rb") as f:
    s = io.BytesIO(bytes(f.read()))
print(bytes(s))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 4
#       2 with open("domo.docx","rb") as f:
#       3     s = io.BytesIO(bytes(f.read()))
# ----> 4 print(bytes(s))
#
# TypeError: 'bytes' object cannot be interpreted as an integer
