# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
marks_m = np.array([77,88,78,34,98])

gen = np.array(["m","m","f","m","f"])
students=np.array([x for x in range(len(marks))])
fig , ax = plt.subplots(figsize=(8,5))
ax.bar(students,marks)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 marks_m = np.array([77,88,78,34,98])
#       3 gen = np.array(["m","m","f","m","f"])
# ----> 4 students=np.array([x for x in range(len(marks))])
#       5 fig , ax = plt.subplots(figsize=(8,5))
#       6 ax.bar(students,marks)
#
# NameError: name 'marks' is not defined

# %%
br = np.array(["a","b","c","d","e"])
marks_m = np.array([77,88,78,34,98])
marks_p = np.array([88,98,45,75,65])

fig , ax = plt.subplots(figsize=(8,5))
width = 0.35
x = np.array([i for i in range(len(br))])
bar1 = ax.bar(x-width/2,marks_m,edgecolor="black",alpha=0.85,width=width,label="math")
bar2 = ax.bar(x+width/2,marks_p,edgecolor="black",alpha=0.85,width=width,label="phy")

ax.set_xticks(x)           # place ticks at center of each group
ax.set_xticklabels(br)     # label them a,b,c,d,e
ax.legend()
ax.bar_label(bar1, fmt="%d", padding=3, fontsize=9)
ax.bar_label(bar2, fmt="%d", padding=3, fontsize=9)

plt.tight_layout() 
plt.show()
