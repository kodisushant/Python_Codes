# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
df =pd.read_csv('Housing.csv')
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
plt.scatter(df['area'],df['price'])
plt.xlabel('Area')
plt.ylabel('Price')
plt.title('Area v/s Price Graph')
plt.grid()
plt.show()

# %%
x=df.iloc[:,1:2]
y=df.iloc[:,0:1]
print(x.shape)
print(y.shape)
# Out:
# (545, 1)
# (545, 1)

# %%
x.head()
# Out:
#    area
# 0  7420
# 1  8960
# 2  9960
# 3  7500
# 4  7420

# %%
y.head()
# Out:
#       price
# 0  13300000
# 1  12250000
# 2  12250000
# 3  12215000
# 4  11410000

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test= train_test_split(x,y,test_size=0.3,random_state=2)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
ypred = lr.predict(X_test)

# %%
print(lr.coef_)
print(lr.intercept_)
# Out:
# [[481.58851797]]
# [2285422.07211824]

# %%
lr.predict([X_test.iloc[0].values])
# Out:
# C:\Users\susha\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[3730187.62601536]])

# %%
print(lr.predict([[7420]]))
# Out:
# [[5858808.87542377]]
# C:\Users\susha\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.scatter(df['area'],df['price'])
plt.plot(X_train,lr.predict(X_train),color='red')
plt.xlabel('Area')
plt.ylabel('Price')
plt.title('Area v/s Price Graph')
plt.grid()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

y_pred = lr.predict(X_test)

MAE  = mean_absolute_error(y_test, y_pred)
MSE  = mean_squared_error(y_test, y_pred)
RMSE = np.sqrt(MSE)
R2   = r2_score(y_test, y_pred)

n = len(y_test)
k = X_test.shape[1]
Adj_R2 = 1 - (1 - R2) * (n - 1) / (n - k - 1)

print(f"MAE       : ₹{MAE:,.0f}")
print(f"MSE       : {MSE:,.0f}")
print(f"RMSE      : ₹{RMSE:,.0f}")
print(f"R²        : {R2:.4f}")
print(f"Adj. R²   : {Adj_R2:.4f}")
# Out:
# MAE       : ₹1,194,334
# MSE       : 2,700,228,821,961
# RMSE      : ₹1,643,237
# R²        : 0.2653
# Adj. R²   : 0.2608

# %%
plt.scatter(df['stories'],df['price'])
plt.xlabel('Stories')
plt.ylabel('Price')
plt.title('Stories v/s Price Graph')
plt.grid()
plt.show()

# %%
x=df.iloc[:,4:5]
y=df.iloc[:,0:1]
print(x.shape)
print(y.shape)
# Out:
# (545, 1)
# (545, 1)

# %%
x.head()
# Out:
#    stories
# 0        3
# 1        4
# 2        2
# 3        2
# 4        2

# %%
y.head()
# Out:
#       price
# 0  13300000
# 1  12250000
# 2  12250000
# 3  12215000
# 4  11410000

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test= train_test_split(x,y,test_size=0.3,random_state=2)
print(X_train)
print(X_test)
# Out:
#      stories
# 166        1
# 378        3
# 349        2
# 368        1
# 306        2
# ..       ...
# 299        1
# 534        2
# 493        1
# 527        1
# 168        2
#
# [381 rows x 1 columns]
#      stories
# 333        2
# 84         2
# 439        1
# 396        1
# 161        3
# ..       ...
# 117        2
# 314        2
# 340        2
# 444        2
# 307        2
#
# [164 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
print(lr.coef_)
print(lr.intercept_)
# Out:
# [[876467.44235674]]
# [3141071.12892313]

# %%
plt.scatter(df['stories'],df['price'])
plt.plot(X_train,lr.predict(X_train),color='red')
plt.xlabel('Stories')
plt.ylabel('Price')
plt.title('Stories v/s Price Graph')
plt.grid()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
y_pred = lr.predict(X_test)

MAE  = mean_absolute_error(y_test, y_pred)
MSE  = mean_squared_error(y_test, y_pred)
RMSE = np.sqrt(MSE)
R2   = r2_score(y_test, y_pred)

n = len(y_test)
k = X_test.shape[1]
Adj_R2 = 1 - (1 - R2) * (n - 1) / (n - k - 1)

print(f"MAE       : ₹{MAE:,.0f}")
print(f"MSE       : {MSE:,.0f}")
print(f"RMSE      : ₹{RMSE:,.0f}")
print(f"R²        : {R2:.4f}")
print(f"Adj. R²   : {Adj_R2:.4f}")
# Out:
# MAE       : ₹1,287,144
# MSE       : 3,051,821,595,376
# RMSE      : ₹1,746,946
# R²        : 0.1697
# Adj. R²   : 0.1645

# %%
plt.scatter(df['bedrooms'],df['parking'])
plt.xlabel('Bedrooms')
plt.ylabel('Parking')
plt.title('Bedrooms v/s Parking')
plt.grid()
plt.show()

# %%
x=df.iloc[:,2:3]
y=df.iloc[:,10:11]
print(x.shape)
print(y.shape)
# Out:
# (545, 1)
# (545, 1)

# %%
x.head()
# Out:
#    bedrooms
# 0         4
# 1         4
# 2         3
# 3         4
# 4         4

# %%
y.head()
# Out:
#    parking
# 0        2
# 1        3
# 2        2
# 3        3
# 4        2

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test= train_test_split(x,y,test_size=0.3,random_state=2)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
print(lr.coef_)
print(lr.intercept_)
# Out:
# [[0.23051844]]
# [-0.0097542]

# %%
plt.scatter(df['bedrooms'],df['parking'])
plt.plot(X_train,lr.predict(X_train),color='red')
plt.xlabel('Bedrooms')
plt.ylabel('Parking')
plt.title('Bedrooms v/s Parking')
plt.grid()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
y_pred = lr.predict(X_test)

MAE  = mean_absolute_error(y_test, y_pred)
MSE  = mean_squared_error(y_test, y_pred)
RMSE = np.sqrt(MSE)
R2   = r2_score(y_test, y_pred)

n = len(y_test)
k = X_test.shape[1]
Adj_R2 = 1 - (1 - R2) * (n - 1) / (n - k - 1)

print(f"MAE       : ₹{MAE:,.0f}")
print(f"MSE       : {MSE:,.0f}")
print(f"RMSE      : ₹{RMSE:,.0f}")
print(f"R²        : {R2:.4f}")
print(f"Adj. R²   : {Adj_R2:.4f}")
# Out:
# MAE       : ₹1
# MSE       : 1
# RMSE      : ₹1
# R²        : -0.0355
# Adj. R²   : -0.0419

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >
