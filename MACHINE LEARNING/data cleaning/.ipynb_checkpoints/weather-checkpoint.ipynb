# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("weather_dirty_dataset.csv")

# %%
'''
to change data type
1.mintemp,maxtemp,rainfall to float

'''
df.isnull().sum()
# Out:
# ObservationID     0
# Date              0
# Location          0
# MinTemp           0
# MaxTemp           0
# Rainfall          0
# Evaporation      82
# Sunshine         80
# WindGustDir      81
# WindGustSpeed     0
# WindDir9am        0
# WindDir3pm        0
# WindSpeed9am      0
# WindSpeed3pm      0
# Humidity9am       0
# Humidity3pm       0
# Pressure9am      81
# Pressure3pm      81
# Cloud9am         82
# Cloud3pm         80
# Temp9am           0
# Temp3pm           0
# RainToday         0
# UVIndex           0
# Visibility_km     0
# DewPoint         81
# RainTomorrow      0
# dtype: int64

# %%
df.dtypes
# Out:
# ObservationID     object
# Date              object
# Location          object
# MinTemp           object
# MaxTemp           object
# Rainfall          object
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed      int64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am        int64
# Humidity3pm        int64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# UVIndex            int64
# Visibility_km    float64
# DewPoint         float64
# RainTomorrow      object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1015 entries, 0 to 1014
# Data columns (total 27 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ObservationID  1015 non-null   object
#  1   Date           1015 non-null   object
#  2   Location       1015 non-null   object
#  3   MinTemp        1015 non-null   object
#  4   MaxTemp        1015 non-null   object
#  5   Rainfall       1015 non-null   object
#  6   Evaporation    933 non-null    float64
#  7   Sunshine       935 non-null    float64
#  8   WindGustDir    934 non-null    object
#  9   WindGustSpeed  1015 non-null   int64
#  10  WindDir9am     1015 non-null   object
#  11  WindDir3pm     1015 non-null   object
#  12  WindSpeed9am   1015 non-null   float64
#  13  WindSpeed3pm   1015 non-null   float64
#  14  Humidity9am    1015 non-null   int64
#  15  Humidity3pm    1015 non-null   int64
#  16  Pressure9am    934 non-null    float64
# ...

# %%
def float_maker(x):
    if pd.isna(x) or x=="": 
        return np.nan
    x= str(x) 
    x= x.replace("Â°C","").replace("°C","").replace("mm","")
    return float(x)

# %%
for col in ["MinTemp","MaxTemp","Rainfall"]:
    df[col] = df[col].apply(float_maker)

# %%
df["MaxTemp"].iloc[108]
# Out:
# np.float64(26.7)

# %%
df.dtypes
# Out:
# ObservationID     object
# Date              object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed      int64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am        int64
# Humidity3pm        int64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# UVIndex            int64
# Visibility_km    float64
# DewPoint         float64
# RainTomorrow      object
# dtype: object

# %%
df.isnull().sum()
# Out:
# ObservationID     0
# Date              0
# Location          0
# MinTemp           0
# MaxTemp           0
# Rainfall          0
# Evaporation      82
# Sunshine         80
# WindGustDir      81
# WindGustSpeed     0
# WindDir9am        0
# WindDir3pm        0
# WindSpeed9am      0
# WindSpeed3pm      0
# Humidity9am       0
# Humidity3pm       0
# Pressure9am      81
# Pressure3pm      81
# Cloud9am         82
# Cloud3pm         80
# Temp9am           0
# Temp3pm           0
# RainToday         0
# UVIndex           0
# Visibility_km     0
# DewPoint         81
# RainTomorrow      0
# dtype: int64

# %%
df[["MinTemp","MaxTemp"]].iloc[100:130]
# Out:
#      MinTemp  MaxTemp
# 100     24.2     36.8
# 101     22.1     33.8
# 102      9.4    200.0
# 103   -200.0     26.8
# 104     16.2     24.1
# 105     11.5     24.3
# 106     13.5    -50.0
# 107     11.2     24.3
# 108     16.3     26.7
# 109     24.6     27.5
# 110     18.9     28.9
# 111     10.3     20.2
# 112     20.6     35.1
# 113     16.9     20.1
# 114     18.2     21.3
# 115     24.8     33.2
# 116     16.5     21.9
# 117      7.8    150.0
# 118     18.6     34.8
# 119     11.1     21.4
# 120     16.2     21.2
# 121   -200.0     28.7
# 122     21.3     37.7
# 123     23.7     27.6
# 124     19.9     31.3
# 125     22.9     31.6
# 126     16.3     22.2
# 127     21.0     30.3
# 128     14.9     24.9
# 129     24.6     27.9

# %%
sns.boxplot(df["MinTemp"])
# Out:
# <Axes: ylabel='MinTemp'>

# %%
df["MinTemp"].describe()
# Out:
# count    1015.000000
# mean       12.684729
# std        23.733474
# min      -200.000000
# 25%        10.800000
# 50%        14.500000
# 75%        19.050000
# max        80.000000
# Name: MinTemp, dtype: float64

# %%
def range_maker(x): 
    q1 = df[x].quantile(0.25)
    q3 = df[x].quantile(0.75)

    iqr = q3 - q1 

    lower = q1 - 1.5*iqr 
    upper = q3 + 1.5*iqr 

    ran = [lower,upper]

    df.loc[ ( (df[x]<lower ) | (df[x]>upper ) ) ,x] = np.nan

# %%
range_maker("MinTemp")

# %%
sns.boxplot(df["MinTemp"])
# Out:
# <Axes: ylabel='MinTemp'>

# %%
sns.boxplot(df["MaxTemp"])
# Out:
# <Axes: ylabel='MaxTemp'>

# %%
range_maker("MaxTemp")

# %%
sns.boxplot(df["MaxTemp"])
# Out:
# <Axes: ylabel='MaxTemp'>

# %%
sns.displot(df["MinTemp"],kde=True)

# %%
sns.displot(df["MaxTemp"],kde=True)

# %%
print(df["MinTemp"].skew())
print(df["MaxTemp"].skew())
# Out:
# 0.18774466288952793
# 0.10835578064048412

# %%
df["MinTemp"] = df["MinTemp"].fillna(df["MinTemp"].median())
df["MaxTemp"] = df["MaxTemp"].fillna(df["MaxTemp"].mean())

# %%
print(df["MaxTemp"].skew())
# Out:
# 0.10949097502732688

# %%
sns.boxplot(df["Rainfall"])
# Out:
# <Axes: ylabel='Rainfall'>

# %%
range_maker("Rainfall")

# %%
sns.boxplot(df["Rainfall"])
# Out:
# <Axes: ylabel='Rainfall'>

# %%
range_maker("Rainfall")

# %%
sns.boxplot(df["Rainfall"])
# Out:
# <Axes: ylabel='Rainfall'>

# %%
sns.displot(df["Rainfall"],kde=True)

# %%
df["Rainfall"].isnull().sum()
# Out:
# np.int64(207)

# %%
print(df["Rainfall"].skew())
# Out:
# 0.13121367587215926

# %%
df.isnull().sum()
# Out:
# ObservationID      0
# Date               0
# Location           0
# MinTemp            0
# MaxTemp            0
# Rainfall         207
# Evaporation       82
# Sunshine          80
# WindGustDir       81
# WindGustSpeed      0
# WindDir9am         0
# WindDir3pm         0
# WindSpeed9am       0
# WindSpeed3pm       0
# Humidity9am        0
# Humidity3pm        0
# Pressure9am       81
# Pressure3pm       81
# Cloud9am          82
# Cloud3pm          80
# Temp9am            0
# Temp3pm            0
# RainToday          0
# UVIndex            0
# Visibility_km      0
# DewPoint          81
# RainTomorrow       0
# dtype: int64

# %%
sns.heatmap(df.isnull(),yticklabels=False)
# Out:
# <Axes: >

# %%
row_nulls = df.isnull().sum(axis=1)
print(row_nulls.value_counts().sort_index())
# Out:
# 0    413
# 1    406
# 2    147
# 3     41
# 4      8
# Name: count, dtype: int64

# %%
cols_check = ['Evaporation','Sunshine','WindGustDir','Pressure9am','Pressure3pm','Cloud9am','Cloud3pm']
df[cols_check].isnull().sum(axis=1).value_counts().sort_index()
# Out:
# 0    568
# 1    344
# 2     87
# 3     15
# 4      1
# Name: count, dtype: int64

# %%
df["Location"].unique()
# Out:
# array(['Adelaide', 'Perth', 'Melbourne', 'Newcastle', 'Darwin',
#        'Canberra', 'Hobart', 'Townsville', 'Sydney', 'Cairns',
#        'Wollongong', 'MELBOURNE', 'Brisbane', 'Adel@ide', 'Brisbone'],
#       dtype=object)

# %%
titleize = lambda x: str(x).title()

# %%
df["Location"] = df["Location"].apply(titleize)

# %%
df["Location"].unique()
# Out:
# array(['Adelaide', 'Perth', 'Melbourne', 'Newcastle', 'Darwin',
#        'Canberra', 'Hobart', 'Townsville', 'Sydney', 'Cairns',
#        'Wollongong', 'Brisbane', 'Adel@Ide', 'Brisbone'], dtype=object)

# %%
df["Location"] = df["Location"].str.replace("Adel@Ide","Adelaide")

# %%
df["Location"].unique()
# Out:
# array(['Adelaide', 'Perth', 'Melbourne', 'Newcastle', 'Darwin',
#        'Canberra', 'Hobart', 'Townsville', 'Sydney', 'Cairns',
#        'Wollongong', 'Brisbane', 'Brisbone'], dtype=object)

# %%
df["Rainfall"] = df.groupby('Location')["Rainfall"].transform(lambda x: x.fillna(x.median()))

# %%
df.dtypes
# Out:
# ObservationID     object
# Date              object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed      int64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am        int64
# Humidity3pm        int64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# UVIndex            int64
# Visibility_km    float64
# DewPoint         float64
# RainTomorrow      object
# dtype: object

# %%
sns.displot(df["Rainfall"],kde=True)

# %%
sns.displot(df["WindSpeed3pm"],kde=True)

# %%
sns.boxplot(df["WindSpeed3pm"])
# Out:
# <Axes: ylabel='WindSpeed3pm'>

# %%
df["Pressure3pm"].isnull().sum()
# Out:
# np.int64(81)

# %%
numeric_cols = ['Evaporation','Sunshine','Pressure9am','Pressure3pm','Cloud9am','Cloud3pm','DewPoint',"WindGustSpeed","WindSpeed9am","WindSpeed3pm","Humidity9am","Humidity3pm","Temp9am","Temp3pm","UVIndex","Visibility_km"]

# %%
num_mean = ["Sunshine","Pressure9am","DewPoint","WindGustSpeed","Temp9am","Temp3pm" ]
num_med = ["Evaporation","Pressure3pm","Cloud9am","Cloud3pm","WindGustSpeed","WindSpeed9am","WindSpeed3pm","Humidity9am" ,"Humidity3pm","UVIndex","Visibility_km"]

# %%
df.loc[df["WindSpeed3pm"] < 0, "WindSpeed3pm"] = np.nan
df.loc[df["WindSpeed9am"] < 0, "WindSpeed9am"] = np.nan

# %%
for col in numeric_cols:
    range_maker(col)

# %%
for col in num_mean: 
    df[col] = df[col].fillna(df[col].mean())

# %%
for col in num_med:
    df[col] = df[col].fillna(df[col].median())

# %%
df["Pressure3pm"].isnull().sum()
# Out:
# np.int64(0)

# %%
sns.boxplot(df["Pressure3pm"])
# Out:
# <Axes: ylabel='Pressure3pm'>

# %%
sns.heatmap(df.isnull(),yticklabels=False)
# Out:
# <Axes: >

# %%
df["WindGustDir"] = df["WindGustDir"].fillna(df["WindGustDir"].mode()[0])

# %%
sns.heatmap(df.isnull(),yticklabels=False)
# Out:
# <Axes: >

# %%
y = ["1","Y","TRUE","True"]
n = ["0","N","FALSE","False"]

# %%
df[["RainToday","RainTomorrow"]] = (
    df[["RainToday","RainTomorrow"]]
    .replace(y, "Yes")
    .replace(n, "No")
)

# %%
df[["RainToday","RainTomorrow"]] = (
    df[["RainToday","RainTomorrow"]]
    .apply(lambda col: col.str.strip().str.title())
)

# %%
df["RainTomorrow"].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
print(repr(df["RainTomorrow"].iloc[0]))
print(len(str(df["RainTomorrow"].iloc[0])))
# Out:
# 'Yes'
# 3

# %%
sns.heatmap(df.isnull(),yticklabels=False)
# Out:
# <Axes: >

# %%
df.to_csv("Cleaned_Weather.csv")

# %%
from sklearn.preprocessing import MinMaxScaler , StandardScaler

cols_scale = [
    'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
    'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am',
    'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm',
    'Temp9am', 'Temp3pm', 'DewPoint', 'UVIndex', 'Visibility_km'
]

# %%
df_norm = df.copy()

scaler_norm = MinMaxScaler()

df_norm[cols_scale] = scaler_norm.fit_transform(df[cols_scale])

df_norm.to_csv("cleaned_weather_normalised.csv")

# %%
df_stdz = df.copy() 

scaler_stdz = StandardScaler() 

df_stdz[cols_scale] = scaler_stdz.fit_transform(df[cols_scale])

df_stdz.to_csv("cleaned_weather_standardized.csv")
