# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('messy_ecommerce_sales_data-selected-columns.csv')

# %%
df.head()
# Out:
#     ID  Customer_Name   Order_ID  Order_Date        Product  Category  \
# 0  100            NaN  ORD-41285  11/22/2024        Blender       NaN
# 1  101            NaN  ORD-35783    7/5/2025     Smartphone       NaN
# 2  102            NaN  ORD-84355  12/23/2024  Tennis Racket       NaN
# 3  103            NaN  ORD-57811   3/19/2025        Science       NaN
# 4  104            NaN  ORD-93614  10/20/2025      Biography       NaN
#
#   Quantity   Price    Payment_Method      Status
# 0        3      38  Cash on Delivery     Shipped
# 1        2     abd            PayPal  Processing
# 2        1  389.05            PayPal   Delivered
# 3        5  233.92            PayPal  Processing
# 4        1  552.51  Cash on Delivery  Processing

# %%
df['Status'].unique()
# Out:
# array(['Shipped', 'Processing', 'Delivered', 'Cancelled', 'Returned'],
#       dtype=object)
