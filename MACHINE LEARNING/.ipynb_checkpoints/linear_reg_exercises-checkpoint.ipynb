# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df1 = pd.read_csv("Car_Price.csv")
df1.head()
# Out:
#    Mileage_kmpl  Price_Lakhs
# 0          10.0         4.00
# 1          10.3         4.15
# 2          10.6         4.30
# 3          10.9         4.45
# 4          11.2         4.60

# %%
plt.scatter(x=df1["Mileage_kmpl"],y=df1["Price_Lakhs"])

# %%
x1 = df1.iloc[:,:-1]
y1 = df1.iloc[:,-1]
x1.head()
# Out:
#    Mileage_kmpl
# 0          10.0
# 1          10.3
# 2          10.6
# 3          10.9
# 4          11.2

# %%
from sklearn.model_selection import train_test_split
x_train1 , x_test1 , y_train1 , y_test1 = train_test_split(x1,y1,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression 
lr = LinearRegression()

# %%
lr.fit(x_train1,y_train1)
# Out:
# LinearRegression()

# %%
y_pred1 = lr.predict(x_test1 )

# %%
from sklearn.metrics import r2_score 
score = r2_score(y_test1,y_pred1)
print(round(score*100,2))
# Out:
# 100.0

# %%
m1 = lr.coef_[0]
c1 = lr.intercept_
print(m1,c1)
# Out:
# 0.49999999999999983 -0.9999999999999964

# %%
sns.regplot(x=df1["Mileage_kmpl"],y=df1["Price_Lakhs"],line_kws={"color":"red"})
# Out:
# <Axes: xlabel='Mileage_kmpl', ylabel='Price_Lakhs'>

# %%
df2 = pd.read_csv("Weather_Temperature.csv")
df2.head()
# Out:
#    Humidity  Temperature
# 0        40         38.0
# 1        41         37.8
# 2        42         37.6
# 3        43         37.4
# 4        44         37.2

# %%
sns.scatterplot(x=df2["Humidity"],y=df2["Temperature"])
# Out:
# <Axes: xlabel='Humidity', ylabel='Temperature'>

# %%
x2 = df2.iloc[:,:-1]
y2 = df2.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train2 , x_test2 , y_train2, y_test2 = train_test_split(x2,y2,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression 
lr2 = LinearRegression()

# %%
lr2.fit(x_train2,y_train2)
# Out:
# LinearRegression()

# %%
y_pred2 = lr2.predict(x_test2)

# %%
from sklearn.metrics import r2_score 
score = r2_score(y_pred2,y_test2)
print(round(score*100,2))
# Out:
# -336.21

# %%
sns.regplot(x=df2["Humidity"],y=df2["Temperature"],line_kws={"color":"red"})
# Out:
# <Axes: xlabel='Humidity', ylabel='Temperature'>

# %%
df3 = pd.read_csv("House_Price.csv")
df3.head()
# Out:
#    Area_sqft  Price_Lakhs
# 0        800         30.0
# 1        850         32.5
# 2        900         35.0
# 3        950         37.5
# 4       1000         40.0

# %%
sns.scatterplot(x=df3["Area_sqft"],y=df3["Price_Lakhs"])
# Out:
# <Axes: xlabel='Area_sqft', ylabel='Price_Lakhs'>

# %%
x3 = df3.iloc[:,:-1]
y3 = df3.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split 
x_train3 , x_test3 , y_train3 , y_test3 = train_test_split(x3,y3,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression 
lr3 = LinearRegression()

# %%
lr3.fit(x_train3,y_train3)
# Out:
# LinearRegression()

# %%
y_pred3 = lr3.predict(x_test3)

# %%
from sklearn.metrics import r2_score 
score3 = r2_score(y_pred3,y_test3)
print(round(score3*100,2))
# Out:
# 100.0
