# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset("car_crashes")

# %%
df.head(15)
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
df.shape
# Out:
# (51, 8)

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(df.corr(numeric_only=True,method="spearman"),annot=True)
# Out:
# <Axes: >

# %%
sns.histplot(data=df,x="speeding",y="total")
# Out:
# <Axes: xlabel='speeding', ylabel='total'>

# %%
sns.pairplot(df)

# %%
sns.jointplot(x="speeding",y="total",data=df,kind="reg")

# %%
sns.jointplot(x="alcohol",y="total",data=df,kind="reg")

# %%
sns.jointplot(x="not_distracted",y="total",data=df,kind="reg")

#'				abbrev'

# %%
sns.jointplot(x="not_distracted",y="speeding",data=df,kind="reg")

# %%
sns.jointplot(x="no_previous",y="total",data=df,kind="hex")

# %%
sns.jointplot(x="ins_premium",y="total",data=df,kind="reg")

# %%
sns.jointplot(x="ins_losses",y="ins_premium",data=df,kind="reg")

# %%
sns.jointplot(x="alcohol",y="no_previous",data=df,kind="reg")
